# %% [markdown]
# Part 1: Imports

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# Part 2: Model Creation Function

# %%
def create_model(input_data, output_data, epochs=10000):
    model = tf.keras.Sequential([
        keras.layers.Dense(units=64, input_shape=[1], activation='relu'),
        keras.layers.Dense(units=64, activation='relu'),
        keras.layers.Dense(units=1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(input_data, output_data, epochs=epochs, verbose=0)
    return model

# %% [markdown]
# Part 3: Example Usage - Data Preparation

# %%
xs = np.array([1, 2, 3, 4, 5, 6], dtype=float)
ys = np.exp(xs)

# %% [markdown]
# Part 4: Example Usage - Model Training

# %%
model = create_model(xs, ys)

# %% [markdown]
# Part 5: Example Usage - Prediction and Plotting

# %%
x_values = np.linspace(1, 6, 100)
y_predictions = model.predict(x_values)

plt.figure(figsize=(10, 6))
plt.plot(xs, ys, 'bo', label='Original Data') 
plt.plot(x_values, y_predictions, 'r-', label='Predicted Data') 
plt.xlabel('x')
plt.ylabel('y')
plt.title('Exponential Function Prediction')
plt.legend()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
